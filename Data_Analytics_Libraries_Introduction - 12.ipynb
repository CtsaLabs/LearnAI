# %% [markdown]
# # Introduction to Data Analytics Libraries
#
# Data analytics involves analyzing raw data to find trends and answer questions. The Python ecosystem has robust libraries for data analytics; Numpy, Pandas, and Seaborn are foundational tools that enable efficient data analysis and visualization.
#
# ## Numpy
# Numpy is a library for the Python programming language, adding support for large, multi-dimensional arrays and matrices, along with a large collection of high-level mathematical functions to operate on these arrays.
#
# ## Pandas
# Pandas is an open-source, BSD-licensed library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language.
#
# ## Seaborn
# Seaborn is a Python visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.

# %% [markdown]
# ## Getting Started with Numpy
#
# Numpy is the core library for numerical computations in Python. It provides a high-performance multidimensional array object and tools for working with these arrays.

# %% [markdown]
# ### Basic Numpy Arrays
# ```python
# import numpy as np
#
# a = np.array([1, 2, 3])
# print(a)
# ```

# %%
#import statement

# %%
# for new installation you us
#pip install numpy

# %%
import numpy

# %%
#np as the alias because of convention
import numpy as np

# %%
# single dimension array
arr1 = np.array([1,3,5,7,4,6])

# %%
type(arr1)
# Out:
# numpy.ndarray

# %%
arr1
# Out:
# array([1, 3, 5, 7, 4, 6])

# %%
#2d array
np.array([[1,3,5,7],[2,5,7,8]])
# Out:
# array([[1, 3, 5, 7],
#        [2, 5, 7, 8]])

# %%
#2d array
np.array([[1,3,5,7],[2,5,7,8]], dtype=float)
# Out:
# array([[1., 3., 5., 7.],
#        [2., 5., 7., 8.]])

# %%
dim = np.array([[1,3,5,7],[2,5,7,8]], dtype=float)

# %%
# shape or dimension
dim.shape

# 2 rows, 4 columns
# Out:
# (2, 4)

# %% [markdown]
# ### Operations with Numpy Arrays
# Numpy arrays support various operations, which are performed element-wise.
# ```python
# b = np.array([4, 5, 6])
#
# # Element-wise addition
# print(a + b)
#
# # Element-wise multiplication
# print(a * b)
# ```

# %%
arr1
# Out:
# array([1, 3, 5, 7, 4, 6])

# %%
list2 = [3, 5, 6, 8, 10, 15]

# %%
arr2 = np.array(list2)

# %%
arr2
# Out:
# array([ 3,  5,  6,  8, 10, 15])

# %%
arr1 + arr2
# Out:
# array([ 4,  8, 11, 15, 14, 21])

# %%
# no element-wise with different shape

arr3 = np.array([2,4,6])

# %%
arr1 + arr3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 arr1 + arr3
#
# ValueError: operands could not be broadcast together with shapes (6,) (3,)

# %%
#broadcasting

# %%
list2
# Out:
# [3, 5, 6, 8, 10, 15]

# %%
for i in list2:
    print(i + 5)
# Out:
# 8
# 10
# 11
# 13
# 15
# 20

# %%
arr1
# Out:
# array([1, 3, 5, 7, 4, 6])

# %%
#broadcasting
arr1 * 5
# Out:
# array([ 5, 15, 25, 35, 20, 30])

# %% [markdown]
# ### Working with Mathematical Functions
# Numpy provides a vast array of mathematical functions to perform operations on arrays.

# %%
square root
mean
max
min
avg
ceil
log

# %%
arr1
# Out:
# array([1, 3, 5, 7, 4, 6])

# %%
np.max(arr1)
# Out:
# 7

# %%
np.min(arr1)
# Out:
# 1

# %%
np.average(arr1)
# Out:
# 4.333333333333333

# %%
np.sum(arr1)
# Out:
# 26

# %%
#this is done element-wise
np.sqrt(arr1)
# Out:
# array([1.        , 1.73205081, 2.23606798, 2.64575131, 2.        ,
#        2.44948974])

# %%
np.square(arr1)
# Out:
# array([ 1,  9, 25, 49, 16, 36], dtype=int32)

# %%
np.exp(arr1)
# Out:
# array([   2.71828183,   20.08553692,  148.4131591 , 1096.63315843,
#          54.59815003,  403.42879349])

# %%
np.log(arr2)
# Out:
# array([1.09861229, 1.60943791, 1.79175947, 2.07944154, 2.30258509,
#        2.7080502 ])

# %%
# Mathematical functions
np.sqrt(arr)
np.log(arr)

# %% [markdown]
# ## Exploring Data with Pandas
#
# Pandas is a library offering high-performance, easy-to-use data structures, and data analysis tools. The DataFrame is one of Pandas' most important classes.

# %% [markdown]
# ### Creating a DataFrame
# ```python
# import pandas as pd
#
# data = {'Name': ['John', 'Anna', 'Peter', 'Linda'],
#         'Age': [28, 34, 29, 32]}
# df = pd.DataFrame(data)
# print(df)
# ```

# %%
import pandas as pd

# %%
#you create a dataframe using a dictionary

# %%
data = {'Name': ['Lekan', 'Olaoluwa', 'Peter', 'Suliman'], 'Age': [20,35, 70, 90], 'Income':[5000, 7000, 8000, 6500]}

# %%
data
# Out:
# {'Name': ['Lekan', 'Olaoluwa', 'Peter', 'Suliman'],
#  'Age': [20, 35, 70, 90],
#  'Income': [5000, 7000, 8000, 6500]}

# %%
type(data)

pd.DataFrame(data)
# Out:
#        Name  Age  Income
# 0     Lekan   20    5000
# 1  Olaoluwa   35    7000
# 2     Peter   70    8000
# 3   Suliman   90    6500

# %%
pd.DataFrame(data)
# Out:
#        Name  Age  Income
# 0     Lekan   20    5000
# 1  Olaoluwa   35    7000
# 2     Peter   70    8000
# 3   Suliman   90    6500

# %%
#storing to a variable
df = pd.DataFrame(data)

# %%
df
# Out:
#        Name  Age  Income
# 0     Lekan   20    5000
# 1  Olaoluwa   35    7000
# 2     Peter   70    8000
# 3   Suliman   90    6500

# %% [markdown]
# ### Reading Data from Files
# Pandas can easily read data stored in different file formats like CSV, Excel, or JSON.
# ```python
# df = pd.read_csv('filename.csv')
# ```

# %%
pd.read

# %%
df = pd.read_csv('Supermarket.csv')

# %%
xc=pd.read_csv('Supermarket.csv')
xc.head()
# Out:
#   Product Identifier Supermarket Identifier Product Supermarket Identifer  \
# 0              NCA29            CHUKWUDI046             NCA29_CHUKWUDI046
# 1              FDG53            CHUKWUDI049             FDG53_CHUKWUDI049
# 2              NCN05            CHUKWUDI045             NCN05_CHUKWUDI045
# 3              NCV17            CHUKWUDI046             NCV17_CHUKWUDI046
# 4              FDK03            CHUKWUDI045             FDK03_CHUKWUDI045
#
#    Product Weight Product Fat Content  Product Shelf Visibility  \
# 0          10.500              Lo Fat                  0.027276
# 1          10.000             Low Fat                  0.045928
# 2           8.235              Lo Fat                  0.014489
# 3          18.850             Low Fat                  0.016108
# 4          12.600          Normal Fat                  0.074070
#
#          Product Type  Product Price Supermarket Opening Year  \
# 0           Household         428.28                     2004
# 1        Frozen Foods         345.30                     2006
# 2  Health and Hygiene         459.49                     2009
# 3  Health and Hygiene         324.41                     2004
# 4               Dairy         635.59                     2009
#
#   Supermarket  Size Supermarket Location Type   Supermarket Type  \
# 0             Small                 Cluster 1  Supermarket Type1
# 1            Medium                 Cluster 1  Supermarket Type1
# 2               NaN                 Cluster 2  Supermarket Type1
# 3             Small                 Cluster 1  Supermarket Type1
# 4               NaN                 Cluster 2  Supermarket Type1
#
#   Average Price per ProductType  Product Supermarket Sales
# 0                    399.999418                    8983.31
# 1                   388.0710941                    4893.63
# 2                   367.1430293                    7323.80
# 3                   367.1430293                    7541.85
# 4                   409.5043429                   11445.10

# %%
df.shape
# Out:
# (2994, 14)

# %%
df.head()
# Out:
#   Product Identifier Supermarket Identifier Product Supermarket Identifer  \
# 0              NCA29            CHUKWUDI046             NCA29_CHUKWUDI046
# 1              FDG53            CHUKWUDI049             FDG53_CHUKWUDI049
# 2              NCN05            CHUKWUDI045             NCN05_CHUKWUDI045
# 3              NCV17            CHUKWUDI046             NCV17_CHUKWUDI046
# 4              FDK03            CHUKWUDI045             FDK03_CHUKWUDI045
#
#    Product Weight Product Fat Content  Product Shelf Visibility  \
# 0          10.500              Lo Fat                  0.027276
# 1          10.000             Low Fat                  0.045928
# 2           8.235              Lo Fat                  0.014489
# 3          18.850             Low Fat                  0.016108
# 4          12.600          Normal Fat                  0.074070
#
#          Product Type  Product Price Supermarket Opening Year  \
# 0           Household         428.28                     2004
# 1        Frozen Foods         345.30                     2006
# 2  Health and Hygiene         459.49                     2009
# 3  Health and Hygiene         324.41                     2004
# 4               Dairy         635.59                     2009
#
#   Supermarket  Size Supermarket Location Type   Supermarket Type  \
# 0             Small                 Cluster 1  Supermarket Type1
# 1            Medium                 Cluster 1  Supermarket Type1
# 2               NaN                 Cluster 2  Supermarket Type1
# 3             Small                 Cluster 1  Supermarket Type1
# 4               NaN                 Cluster 2  Supermarket Type1
#
#   Average Price per ProductType  Product Supermarket Sales
# 0                    399.999418                    8983.31
# 1                   388.0710941                    4893.63
# 2                   367.1430293                    7323.80
# 3                   367.1430293                    7541.85
# 4                   409.5043429                   11445.10

# %%
df.tail()
# Out:
#      Product Identifier Supermarket Identifier Product Supermarket Identifer  \
# 2989              FDK21            CHUKWUDI045             FDK21_CHUKWUDI045
# 2990              NCJ05            CHUKWUDI049             NCJ05_CHUKWUDI049
# 2991              FDI04            CHUKWUDI019             FDI04_CHUKWUDI019
# 2992              DRG37            CHUKWUDI013             DRG37_CHUKWUDI013
# 2993              FDE51            CHUKWUDI013             FDE51_CHUKWUDI013
#
#       Product Weight Product Fat Content  Product Shelf Visibility  \
# 2989           7.905             Low Fat                  0.010033
# 2990          18.700             Low Fat                  0.046160
# 2991             NaN          Normal Fat                  0.127660
# 2992          16.200             Low Fat                  0.019362
# 2993           5.925          Normal Fat                  0.096387
#
#             Product Type  Product Price Supermarket Opening Year  \
# 2989         Snack Foods         620.85                     2009
# 2990  Health and Hygiene         380.92                     2006
# 2991        Frozen Foods         496.36                     1992
# 2992         Soft Drinks         386.74                     1994
# 2993               Dairy         114.02                     1994
#
#      Supermarket  Size Supermarket Location Type   Supermarket Type  \
# 2989               NaN                 Cluster 2  Supermarket Type1
# 2990            Medium                 Cluster 1  Supermarket Type1
# 2991             small                 Cluster 1      Grocery Store
# 2992              High                 Cluster 3  Supermarket Type1
# 2993              High                 Cluster 3  Supermarket Type1
#
#      Average Price per ProductType  Product Supermarket Sales
# 2989                     395.35219                    1877.56
# 2990                   367.1430293                    4192.88
# 2991                   388.0710941                    1977.43
# 2992                   386.9982375                    4284.42
# 2993                   409.5043429                     892.17

# %%
df.shape
# Out:
# (2994, 14)

# %%
#slicing
df[2:15]
# Out:
#    Product Identifier Supermarket Identifier Product Supermarket Identifer  \
# 2               NCN05            CHUKWUDI045             NCN05_CHUKWUDI045
# 3               NCV17            CHUKWUDI046             NCV17_CHUKWUDI046
# 4               FDK03            CHUKWUDI045             FDK03_CHUKWUDI045
# 5               FDV02            CHUKWUDI027             FDV02_CHUKWUDI027
# 6               FDF17            CHUKWUDI017             FDF17_CHUKWUDI017
# 7               FDA26            CHUKWUDI019             FDA26_CHUKWUDI019
# 8               FDZ09            CHUKWUDI049             FDZ09_CHUKWUDI049
# 9               FDL08            CHUKWUDI027             FDL08_CHUKWUDI027
# 10              FDW20            CHUKWUDI010             FDW20_CHUKWUDI010
# 11              FDX44            CHUKWUDI013             FDX44_CHUKWUDI013
# 12              NCI29            CHUKWUDI017             NCI29_CHUKWUDI017
# 13              FDZ10            CHUKWUDI013             FDZ10_CHUKWUDI013
# 14              FDN44            CHUKWUDI017             FDN44_CHUKWUDI017
#
#     Product Weight Product Fat Content  Product Shelf Visibility  \
# 2            8.235              Lo Fat                  0.014489
# 3           18.850             Low Fat                  0.016108
# 4           12.600          Normal Fat                  0.074070
# 5              NaN             Low Fat                  0.060252
# 6            5.190             Low Fat                  0.042862
# 7              NaN           Norml Fat                  0.129425
# 8           17.600             Low Fat                  0.105042
# 9              NaN              Lo Fat                  0.049478
# 10          20.750             Low Fat                  0.040421
# 11           9.300             Low Fat                  0.042931
# 12           8.600             Low Fat                  0.032806
# 13          17.850             Low Fat                  0.044426
# 14          13.150       Ultra Low fat                  0.022925
#
#              Product Type  Product Price Supermarket Opening Year  \
# 2      Health and Hygiene         459.49                     2009
# 3      Health and Hygiene         324.41                     2004
# 4                   Dairy         635.59                     2009
# 5                   Dairy         426.78                     1992
# 6            Frozen Foods         492.03                     2014
# 7                   Dairy         548.37                     1992
# 8             Snack Foods         409.72                     s006
# 9          Fruits and Veg         613.54                     1992
# 10  Fruits and Vegetables         305.43                     2005
# 11  Fruits and Vegetables         221.29                     1994
# 12     Health and Hygiene         359.04                     2014
# 13            Snack Foods         312.26                     1994
# 14         Fruits and Veg         394.73                     2014
#
#    Supermarket  Size Supermarket Location Type   Supermarket Type  \
# 2                NaN                 Cluster 2  Supermarket Type1
# 3              Small                 Cluster 1  Supermarket Type1
# 4                NaN                 Cluster 2  Supermarket Type1
# 5             Medium                 Cluster 3  Supermarket Type3
# 6                NaN                 Cluster 2  Supermarket Type1
# 7              Small                 Cluster 1      Grocery Store
# 8             Medium                 Cluster 1  Supermarket Type1
# 9             Medium                 Cluster 3  Supermarket Type3
# 10               NaN                 Cluster 3      Grocery Store
# 11              High                 Cluster 3  Supermarket Type1
# 12               NaN                 Cluster 2  Supermarket Type1
# 13              High                 Cluster 3  Supermarket Type1
# 14               NaN                 Cluster 2  Supermarket Type1
#
#    Average Price per ProductType  Product Supermarket Sales
# 2                    367.1430293                    7323.80
# 3                    367.1430293                    7541.85
# 4                    409.5043429                   11445.10
# 5                    409.5043429                    7699.98
# 6                    388.0710941                    9329.52
# 7                    409.5043429                     547.62
# 8                      395.35219                    7779.87
# 9                    398.2481124                    9188.04
# 10                   398.2481124                     923.80
# 11                   398.2481124                    3568.69
# 12                   367.1430293                    5318.08
# 13                     395.35219                    4743.83
# 14                   398.2481124                    4793.76

# %%
df.dtypes
# Out:
# Product Identifier                object
# Supermarket Identifier            object
# Product Supermarket Identifer     object
# Product Weight                   float64
# Product Fat Content               object
# Product Shelf Visibility         float64
# Product Type                      object
# Product Price                    float64
# Supermarket Opening Year          object
# Supermarket  Size                 object
# Supermarket Location Type         object
# Supermarket Type                  object
# Average Price per ProductType     object
# Product Supermarket Sales        float64
# dtype: object

# %%
df.describe()
# Out:
#        Product Weight  Product Shelf Visibility  Product Price  \
# count     2521.000000               2994.000000    2994.000000
# mean        12.833300                  0.065242     393.135665
# std          4.662013                  0.051478     120.023567
# min          4.555000                  0.000000      78.730000
# 25%          8.770000                  0.026461     310.310000
# 50%         12.500000                  0.051954     395.400000
# 75%         17.000000                  0.093863     465.850000
# max         21.350000                  0.309390     661.980000
#
#        Product Supermarket Sales
# count                2994.000000
# mean                 6168.377255
# std                  4491.389399
# min                    83.230000
# 25%                  2808.427500
# 50%                  5467.880000
# 75%                  8554.697500
# max                 32717.410000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2994 entries, 0 to 2993
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Product Identifier             2994 non-null   object
#  1   Supermarket Identifier         2994 non-null   object
#  2   Product Supermarket Identifer  2994 non-null   object
#  3   Product Weight                 2521 non-null   float64
#  4   Product Fat Content            2994 non-null   object
#  5   Product Shelf Visibility       2994 non-null   float64
#  6   Product Type                   2994 non-null   object
#  7   Product Price                  2994 non-null   float64
#  8   Supermarket Opening Year       2994 non-null   object
#  9   Supermarket  Size              2107 non-null   object
#  10  Supermarket Location Type      2994 non-null   object
#  11  Supermarket Type               2994 non-null   object
#  12  Average Price per ProductType  2994 non-null   object
#  13  Product Supermarket Sales      2994 non-null   float64
# dtypes: float64(4), object(10)
# memory usage: 327.6+ KB

# %%
#to check for missing values
df.isna().sum()
# Out:
# Product Identifier                 0
# Supermarket Identifier             0
# Product Supermarket Identifer      0
# Product Weight                   473
# Product Fat Content                0
# Product Shelf Visibility           0
# Product Type                       0
# Product Price                      0
# Supermarket Opening Year           0
# Supermarket  Size                887
# Supermarket Location Type          0
# Supermarket Type                   0
# Average Price per ProductType      0
# Product Supermarket Sales          0
# dtype: int64

# %%
#accessing our columns for data
df['Product Type']
# Out:
# 0                Household
# 1             Frozen Foods
# 2       Health and Hygiene
# 3       Health and Hygiene
# 4                    Dairy
#                ...
# 2989           Snack Foods
# 2990    Health and Hygiene
# 2991          Frozen Foods
# 2992           Soft Drinks
# 2993                 Dairy
# Name: Product Type, Length: 2994, dtype: object

# %%
df[df['Product Type']== 'Dairy']
# Out:
#      Product Identifier Supermarket Identifier Product Supermarket Identifer  \
# 4                 FDK03            CHUKWUDI045             FDK03_CHUKWUDI045
# 5                 FDV02            CHUKWUDI027             FDV02_CHUKWUDI027
# 7                 FDA26            CHUKWUDI019             FDA26_CHUKWUDI019
# 27                FDY15            CHUKWUDI049             FDY15_CHUKWUDI049
# 30                DRG51            CHUKWUDI046             DRG51_CHUKWUDI046
# ...                 ...                    ...                           ...
# 2942              FDV02            CHUKWUDI018             FDV02_CHUKWUDI018
# 2949              FDL39            CHUKWUDI049             FDL39_CHUKWUDI049
# 2955              FDB52            CHUKWUDI045             FDB52_CHUKWUDI045
# 2973              FDA15            CHUKWUDI027             FDA15_CHUKWUDI027
# 2993              FDE51            CHUKWUDI013             FDE51_CHUKWUDI013
#
#       Product Weight Product Fat Content  Product Shelf Visibility  \
# 4             12.600          Normal Fat                  0.074070
# 5                NaN             Low Fat                  0.060252
# 7                NaN           Norml Fat                  0.129425
# 27            18.250          Normal Fat                  0.171094
# 30            12.100             Low Fat                  0.011540
# ...              ...                 ...                       ...
# 2942          16.750             Low Fat                  0.060792
# 2949          16.100          Normal Fat                  0.063430
# 2955          17.750             Low Fat                  0.030497
# 2973             NaN             Low Fat                  0.015945
# 2993           5.925          Normal Fat                  0.096387
#
#      Product Type  Product Price Supermarket Opening Year Supermarket  Size  \
# 4           Dairy         635.59                     2009               NaN
# 5           Dairy         426.78                     1992            Medium
# 7           Dairy         548.37                     1992             Small
# 27          Dairy         389.16                     2006            Medium
# 30          Dairy         408.88                     2004             Small
# ...           ...            ...                      ...               ...
# 2942        Dairy         426.03                     2016            Medium
# 2949        Dairy         448.58                     2006             medim
# 2955        Dairy         642.42                     2009               NaN
# 2973        Dairy         623.77                     1992            Medium
# 2993        Dairy         114.02                     1994              High
#
#      Supermarket Location Type   Supermarket Type  \
# 4                    Cluster 2  Supermarket Type1
# 5                    Cluster 3  Supermarket Type3
# 7                    Cluster 1      Grocery Store
# 27                   Cluster 1  Supermarket Type1
# 30                   Cluster 1  Supermarket Type1
# ...                        ...                ...
# 2942                 Cluster 3  Supermarket Type2
# 2949                 Cluster 1  Supermarket Type1
# 2955                 Cluster 2  Supermarket Type1
# 2973                 Cluster 3  Supermarket Type3
# 2993                 Cluster 3  Supermarket Type1
#
#      Average Price per ProductType  Product Supermarket Sales
# 4                      409.5043429                   11445.10
# 5                      409.5043429                    7699.98
# 7                      409.5043429                     547.62
# 27                     409.5043429                    5085.05
# 30                     409.5043429                    5755.84
# ...                            ...                        ...
# 2942                   409.5043429                    1283.33
# 2949                   409.5043429                    5864.03
# 2955                   409.5043429                    3835.01
# 2973                   409.5043429                   16185.60
# 2993                   409.5043429                     892.17
#
# [193 rows x 14 columns]

# %% [markdown]
# ## comparism in pandas
# & and
# || or
# != not equal to
# == equals to

# %%
df[(df['Product Type']== 'Dairy') & (df['Product Price']>500)]
# Out:
#      Product Identifier Supermarket Identifier Product Supermarket Identifer  \
# 4                 FDK03            CHUKWUDI045             FDK03_CHUKWUDI045
# 7                 FDA26            CHUKWUDI019             FDA26_CHUKWUDI019
# 223               FDW26            CHUKWUDI019             FDW26_CHUKWUDI019
# 422               FDC04            CHUKWUDI019             FDC04_CHUKWUDI019
# 538               FDB15            CHUKWUDI017             FDB15_CHUKWUDI017
# 543               FDI15            CHUKWUDI019             FDI15_CHUKWUDI019
# 585               DRC27            CHUKWUDI035             DRC27_CHUKWUDI035
# 650               FDS50            CHUKWUDI017             FDS50_CHUKWUDI017
# 662               DRD15            CHUKWUDI019             DRD15_CHUKWUDI019
# 748               FDC39            CHUKWUDI017             FDC39_CHUKWUDI017
# 769               DRD15            CHUKWUDI045             DRD15_CHUKWUDI045
# 804               DRD15            CHUKWUDI035             DRD15_CHUKWUDI035
# 839               FDU02            CHUKWUDI017             FDU02_CHUKWUDI017
# 845               DRJ39            CHUKWUDI035             DRJ39_CHUKWUDI035
# 966               FDK51            CHUKWUDI017             FDK51_CHUKWUDI017
# 970               FDC39            CHUKWUDI018             FDC39_CHUKWUDI018
# 1049              FDA15            CHUKWUDI035             FDA15_CHUKWUDI035
# 1059              FDW26            CHUKWUDI045             FDW26_CHUKWUDI045
# 1115              FDW26            CHUKWUDI035             FDW26_CHUKWUDI035
# 1123              DRJ51            CHUKWUDI045             DRJ51_CHUKWUDI045
# 1222              FDY26            CHUKWUDI027             FDY26_CHUKWUDI027
# 1232              FDY26            CHUKWUDI018             FDY26_CHUKWUDI018
# 1240              FDS50            CHUKWUDI049             FDS50_CHUKWUDI049
# 1298              DRJ39            CHUKWUDI045             DRJ39_CHUKWUDI045
# 1312              FDS26            CHUKWUDI027             FDS26_CHUKWUDI027
# 1363              FDA26            CHUKWUDI027             FDA26_CHUKWUDI027
# 1405              FDD39            CHUKWUDI045             FDD39_CHUKWUDI045
# 1563              FDD03            CHUKWUDI035             FDD03_CHUKWUDI035
# 1647              FDW26            CHUKWUDI027             FDW26_CHUKWUDI027
# 1708              FDY02            CHUKWUDI019             FDY02_CHUKWUDI019
# 1711              FDD39            CHUKWUDI017             FDD39_CHUKWUDI017
# 1841              FDF40            CHUKWUDI017             FDF40_CHUKWUDI017
# 1871              FDF40            CHUKWUDI019             FDF40_CHUKWUDI019
# 1930              DRC27            CHUKWUDI017             DRC27_CHUKWUDI017
# 2064              FDW26            CHUKWUDI017             FDW26_CHUKWUDI017
# 2258              FDK03            CHUKWUDI017             FDK03_CHUKWUDI017
# 2345              DRJ51            CHUKWUDI017             DRJ51_CHUKWUDI017
# 2471              FDY38            CHUKWUDI017             FDY38_CHUKWUDI017
# 2520              FDU14            CHUKWUDI035             FDU14_CHUKWUDI035
# 2526              FDA27            CHUKWUDI017             FDA27_CHUKWUDI017
# 2535              FDS26            CHUKWUDI017             FDS26_CHUKWUDI017
# 2546              FDY38            CHUKWUDI019             FDY38_CHUKWUDI019
# 2549              DRJ51            CHUKWUDI035             DRJ51_CHUKWUDI035
# 2574              FDY02            CHUKWUDI017             FDY02_CHUKWUDI017
# 2633              FDU02            CHUKWUDI045             FDU02_CHUKWUDI045
# 2668              FDY26            CHUKWUDI035             FDY26_CHUKWUDI035
# 2701              FDL51            CHUKWUDI035             FDL51_CHUKWUDI035
# 2779              FDX02            CHUKWUDI035             FDX02_CHUKWUDI035
# 2780              FDU02            CHUKWUDI035             FDU02_CHUKWUDI035
# 2789              FDL51            CHUKWUDI049             FDL51_CHUKWUDI049
# 2855              FDA15            CHUKWUDI017             FDA15_CHUKWUDI017
# 2955              FDB52            CHUKWUDI045             FDB52_CHUKWUDI045
# 2973              FDA15            CHUKWUDI027             FDA15_CHUKWUDI027
#
#       Product Weight Product Fat Content  Product Shelf Visibility  \
# 4             12.600          Normal Fat                  0.074070
# 7                NaN           Norml Fat                  0.129425
# 223              NaN          Normal Fat                  0.187443
# 422              NaN             Low Fat                  0.078764
# 538           10.895             Low Fat                  0.137585
# 543              NaN             Low Fat                  0.247490
# 585           13.800             Low Fat                  0.058091
# 650           17.000             Low Fat                  0.055747
# 662              NaN             Low Fat                  0.099442
# 748            7.405             Low Fat                  0.000000
# 769           10.600             Low Fat                  0.056911
# 804           10.600             Low Fat                  0.056785
# 839           13.350             Low Fat                  0.103091
# 845           20.250             Low Fat                  0.036319
# 966           19.850             Low Fat                  0.005265
# 970            7.405             Low Fat                  0.159844
# 1049           9.300             Low Fat                  0.016019
# 1059          11.800          Normal Fat                  0.107274
# 1115          11.800          Normal Fat                  0.107037
# 1123          14.100             Low Fat                  0.088172
# 1222             NaN          Normal Fat                  0.030363
# 1232          20.600          Normal Fat                  0.030635
# 1240          17.000             Low Fat                  0.055520
# 1298          20.250             Low Fat                  0.036400
# 1312             NaN             Low Fat                  0.089036
# 1363             NaN          Normal Fat                  0.073562
# 1405          16.700             Low Fat                  0.070297
# 1563          13.300             Low Fat                  0.079791
# 1647             NaN          Normal Fat                  0.106539
# 1708             NaN          Normal Fat                  0.153457
# 1711          16.700             Low Fat                  0.070552
# 1841          20.250          Normal Fat                  0.022639
# 1871             NaN          Normal Fat                  0.039416
# 1930          13.800             Low Fat                  0.058431
# 2064          11.800          Normal Fat                  0.107663
# 2258          12.600          Normal Fat                  0.074339
# 2345          14.100             Low Fat                  0.088492
# 2471          13.600          Normal Fat                  0.119851
# 2520          17.750             Low Fat                  0.034746
# 2526          20.350          Normal Fat                  0.031103
# 2535          20.350             Low Fat                  0.089975
# 2546             NaN          Normal Fat                  0.208663
# 2549          14.100             Low Fat                  0.087977
# 2574           8.945          Normal Fat                  0.000000
# 2633          13.350             Low Fat                  0.102719
# 2668          20.600          Normal Fat                  0.030505
# 2701          20.700          Normal Fat                  0.047482
# 2779          16.000             Low Fat                  0.057049
# 2780          13.350             Low Fat                  0.102492
# 2789          20.700          Normal Fat                  0.047565
# 2855           9.300       Ultra Low fat                  0.016113
# 2955          17.750             Low Fat                  0.030497
# 2973             NaN             Low Fat                  0.015945
#
#      Product Type  Product Price Supermarket Opening Year Supermarket  Size  \
# 4           Dairy         635.59                     2009               NaN
# 7           Dairy         548.37                     1992             Small
# 223         Dairy         551.19                     1992             Small
# 422         Dairy         603.46                     1992             Small
# 538         Dairy         655.64                     2014               NaN
# 543         Dairy         657.97                     1992             Small
# 585         Dairy         612.95                     2011             Small
# 650         Dairy         550.03                     2014               NaN
# 662         Dairy         582.91                     1992             Small
# 748         Dairy         514.32                     2014               NaN
# 769         Dairy         584.91                     2009               NaN
# 804         Dairy         579.91                     2011             Small
# 839         Dairy         574.84                     2014               NaN
# 845         Dairy         548.37                     2011             Small
# 966         Dairy         661.47                     2014               NaN
# 970         Dairy         516.57                     2016            Medium
# 1049        Dairy         621.27                     2011             Small
# 1059        Dairy         552.94                     2009               NaN
# 1115        Dairy         550.94                     2011             Small
# 1123        Dairy         580.67                     2009               NaN
# 1222        Dairy         526.31                     1992            Medium
# 1232        Dairy         532.31                     2016            Medium
# 1240        Dairy         549.53                     2006            Medium
# 1298        Dairy         548.37                     2009               NaN
# 1312        Dairy         651.40                     1992            Medium
# 1363        Dairy         544.12                     1992            Medium
# 1405        Dairy         540.96                     2009               NaN
# 1563        Dairy         581.83                     2011             Small
# 1647        Dairy         555.94                     1992            Medium
# 1708        Dairy         660.23                     1992             Small
# 1711        Dairy         544.21                     2014               NaN
# 1841        Dairy         621.02                     2014               NaN
# 1871        Dairy         619.52                     1992             Small
# 1930        Dairy         609.20                     2014               NaN
# 2064        Dairy         560.44                     2014               NaN
# 2258        Dairy         638.84                     2014               NaN
# 2345        Dairy         577.92                     2014               NaN
# 2471        Dairy         586.33                     2014               NaN
# 2520        Dairy         620.69                     2011             Small
# 2526        Dairy         643.17                     2014               NaN
# 2535        Dairy         654.15                     2014               NaN
# 2546        Dairy         579.58                     1992             Small
# 2549        Dairy         572.67                     2011             Small
# 2574        Dairy         661.98                     2014               NaN
# 2633        Dairy         572.09                     2009               NaN
# 2668        Dairy         531.56                     2011             Small
# 2701        Dairy         539.97                     2011             Small
# 2779        Dairy         564.85                     2011             Small
# 2780        Dairy         576.34                     2011             Small
# 2789        Dairy         533.72                     2006            Medium
# 2855        Dairy         622.02                     2014               NaN
# 2955        Dairy         642.42                     2009               NaN
# 2973        Dairy         623.77                     1992            Medium
#
#      Supermarket Location Type   Supermarket Type  \
# 4                    Cluster 2  Supermarket Type1
# 7                    Cluster 1      Grocery Store
# 223                  Cluster 1      Grocery Store
# 422                  Cluster 1      Grocery Store
# 538                  Cluster 2  Supermarket Type1
# 543                  Cluster 1      Grocery Store
# 585                  Cluster 2  Supermarket Type1
# 650                  Cluster 2  Supermarket Type1
# 662                  Cluster 1      Grocery Store
# 748                  Cluster 2  Supermarket Type1
# 769                  Cluster 2  Supermarket Type1
# 804                  Cluster 2  Supermarket Type1
# 839                  Cluster 2  Supermarket Type1
# 845                  Cluster 2  Supermarket Type1
# 966                  Cluster 2  Supermarket Type1
# 970                  Cluster 3  Supermarket Type2
# 1049                 Cluster 2  Supermarket Type1
# 1059                 Cluster 2  Supermarket Type1
# 1115                 Cluster 2  Supermarket Type1
# 1123                 Cluster 2  Supermarket Type1
# 1222                 Cluster 3  Supermarket Type3
# 1232                 Cluster 3  Supermarket Type2
# 1240                 Cluster 1  Supermarket Type1
# 1298                 Cluster 2  Supermarket Type1
# 1312                 Cluster 3  Supermarket Type3
# 1363                 Cluster 3  Supermarket Type3
# 1405                 Cluster 2  Supermarket Type1
# 1563                 Cluster 2  Supermarket Type1
# 1647                 Cluster 3  Supermarket Type3
# 1708                 Cluster 1      Grocery Store
# 1711                 Cluster 2  Supermarket Type1
# 1841                 Cluster 2  Supermarket Type1
# 1871                 Cluster 1      Grocery Store
# 1930                 Cluster 2  Supermarket Type1
# 2064                 Cluster 2  Supermarket Type1
# 2258                 Cluster 2  Supermarket Type1
# 2345                 Cluster 2  Supermarket Type1
# 2471                 Cluster 2  Supermarket Type1
# 2520                 Cluster 2  Supermarket Type1
# 2526                 Cluster 2  Supermarket Type1
# 2535                 Cluster 2  Supermarket Type1
# 2546                 Cluster 1      Grocery Store
# 2549                 Cluster 2  Supermarket Type1
# 2574                 Cluster 2  Supermarket Type1
# 2633                 Cluster 2  Supermarket Type1
# 2668                 Cluster 2  Supermarket Type1
# 2701                 Cluster 2  Supermarket Type1
# 2779                 Cluster 2  Supermarket Type1
# 2780                 Cluster 2  Supermarket Type1
# 2789                 Cluster 1  Supermarket Type1
# 2855                 Cluster 2  Supermarket Type1
# 2955                 Cluster 2  Supermarket Type1
# 2973                 Cluster 3  Supermarket Type3
#
#      Average Price per ProductType  Product Supermarket Sales
# 4                      409.5043429                   11445.10
# 7                      409.5043429                     547.62
# 223                    409.5043429                    1111.89
# 422                    409.5043429                    1208.43
# 538                    409.5043429                    9887.13
# 543                    409.5043429                    1324.94
# 585                    409.5043429                   14126.61
# 650                    409.5043429                    5542.79
# 662                    409.5043429                    1742.73
# 748                    409.5043429                   11425.13
# 769                    409.5043429                    9294.57
# 804                    409.5043429                    5228.19
# 839                    409.5043429                    6298.47
# 845                    409.5043429                   12595.27
# 966                    409.5043429                   14574.36
# 970                    409.5043429                    7789.86
# 1049                   409.5043429                   16185.60
# 1059                   409.5043429                    7783.20
# 1115                   409.5043429                   11118.86
# 1123                   409.5043429                   10366.51
# 1222                   409.5043429                   16937.95
# 1232                   409.5043429                    6351.73
# 1240                   409.5043429                    2771.39
# 1298                   409.5043429                   20809.58
# 1312                   409.5043429                   22895.20
# 1363                   409.5043429                    8214.31
# 1405                   409.5043429                    9196.36
# 1563                   409.5043429                    6990.90
# 1647                   409.5043429                    3891.60
# 1708                   409.5043429                     657.48
# 1711                   409.5043429                    5409.63
# 1841                   409.5043429                    5602.71
# 1871                   409.5043429                    1245.05
# 1930                   409.5043429                    4913.60
# 2064                   409.5043429                    7227.26
# 2258                   409.5043429                   24161.88
# 2345                   409.5043429                   19005.26
# 2471                   409.5043429                   16312.10
# 2520                   409.5043429                    2496.75
# 2526                   409.5043429                    5113.34
# 2535                   409.5043429                   18970.31
# 2546                   409.5043429                    1165.15
# 2549                   409.5043429                    8062.84
# 2574                   409.5043429                   11834.60
# 2633                   409.5043429                   13169.52
# 2668                   409.5043429                    8998.29
# 2701                   409.5043429                    8575.50
# 2779                   409.5043429                    3375.61
# 2780                   409.5043429                    6871.06
# 2789                   409.5043429                    4823.72
# 2855                   409.5043429                   14940.55
# 2955                   409.5043429                    3835.01
# 2973                   409.5043429                   16185.60

# %% [markdown]
# # Data Visualisation using SeaBorn

# %%
import seaborn as sns

# %%
pd.value_counts(df['Product Type'])
# Out:
# Product Type
# Fruits and Vegetables    454
# Snack Foods              432
# Household                349
# Frozen Foods             282
# Canned                   221
# Dairy                    193
# Health and Hygiene       186
# Baking Goods             181
# Meat                     168
# Soft Drinks              151
# Hard Drinks               87
# Breads                    81
# Others                    63
# Breakfast                 36
# Starchy Foods             25
# Seafood                   25
# Baking Good               22
# Snack Food                18
# Starchy Food              16
# Fruits and Veg             3
# Health and Hyg             1
# Name: count, dtype: int64

# %%
#VISUALIZING MY DATA USING Seaborn
sns.countplot(y=df['Product Type'], color = 'blue', order =pd.value_counts(df['Product Type']).keys())
# Out:
# <Axes: xlabel='count', ylabel='Product Type'>

# %%
sns.barplot(y='Product Type', x='Product Price', data=df)
# Out:
# <Axes: xlabel='Product Price', ylabel='Product Type'>
